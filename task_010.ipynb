# %%
def describe_person(name, **informace):
    print("Jméno:", name)
    for key, value in informace.items():
        print(f"{key}: {value}")
    if "city" not in informace:
        print("city: unknown")


describe_person("Zuzana", age=28, hobby="šifrovačky", city="Praha")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 def describe_person(name, **informace):
#       2     print("Jméno: ", name)
# ----> 3 for key, value in informace.items():
#       4     print(key, ": ", value)
#       5 if 'city' not in informace.keys():
#
# NameError: name 'informace' is not defined
