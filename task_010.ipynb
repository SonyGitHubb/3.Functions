# %%
def describe_person(name, **informace):
    print("Jméno:", name)
    for key, value in informace.items():
        print(f"{key}: {value}")
    if 'city' not in informace.keys():
        print("city: unknown")

describe_person("Alice", age=30, city="New York", profession="Engineer")
# Out:
# Jméno: Alice
# age: 30
# city: New York
# profession: Engineer
