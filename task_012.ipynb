# %%
def order_food(*items, **details):
    print("Objednané položky:\n ", items)
    print("Detaily objednávky")
    for key, item in details.items():
        print(" ",key,": ", item)
order_food("Pizza", "Salát", table=5, takeaway=True)
# Out:
# Objednané položky:
#   ('Pizza', 'Salát')
# Detaily objednávky
#   table :  5
#   takeaway :  True
